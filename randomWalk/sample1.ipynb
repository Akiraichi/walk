# %%
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from randomWalk.sample1 import *

# np.random.seed(123)

# %matplotlib inline

# %% [markdown]
# ランダムウォークを図で表す。
# 10回、1000回、1000000回の3通りで図で表した。

# %%
df1 = test_1(10, 0.5)
df2 = test_1(100, 0.5)
df3 = test_1(1000, 0.5)

file_name = "単純ランダムウォーク10,100,1000"
plot_axis(file_name,df1)
plot_axis(file_name,df2)
plot_axis(file_name,df3)

# %% [markdown]
# 縦軸のスケールをそれぞれに合わす
