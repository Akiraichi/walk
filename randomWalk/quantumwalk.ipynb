# %%
import numpy as np
import math
from randomWalk import exp_func

# %% [markdown]
# ### 実験名：実験7-1
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} 1 & 0 \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ 0 & 1 \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 1 \\ 0 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果
# ウォーカーはx軸負の方向へ100％進む。

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
# P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
P = np.array([[1, 0], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [0, 1]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
# PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])
PSY[0, 0] = np.array([1, 0])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_7"
exp_code_chapter=1
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験7-2
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} 1 & 0 \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ 0 & 1 \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 0 \\ 1 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果
# ウォーカーはx軸正の方向へ100％進む。

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
# P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
P = np.array([[1, 0], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [0, 1]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
# PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])
PSY[0, 0] = np.array([0, 1])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_7"
exp_code_chapter=2
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験7-3
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} 1 & 0 \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ 0 & 1 \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} \frac{1}{\sqrt{2}} \\ \frac{i}{\sqrt{2}} \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果
# ウォーカーはx軸の方向へ100％進む。

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
P = np.array([[1, 0], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [0, 1]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_7"
exp_code_chapter=3
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験7-4
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} 0 & 1 \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ 1 & 0 \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 1 \\ 0 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果
# ウォーカーはx軸負の方向へ100％進む。

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
P = np.array([[0, 1], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [1, 0]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY[0, 0] = np.array([1, 0])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_7"
exp_code_chapter=4
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験7-5
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} 0 & 1 \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ 1 & 0 \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 0 \\ 1 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果
# ウォーカーはx軸負の方向へ100％進む。

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
# P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
P = np.array([[0, 1], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [1, 0]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
# PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])
PSY[0, 0] = np.array([0, 1])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_7"
exp_code_chapter=5
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験7-6
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} 0 & 1 \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ 1 & 0 \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} \frac{1}{\sqrt{2}} \\ \frac{i}{\sqrt{2}} \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果
# ウォーカーはx軸負の方向へ100％進む。

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
# P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
P = np.array([[0, 1], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [1, 0]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_7"
exp_code_chapter=6
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験8-1
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ \frac{1}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 1 \\ 0 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
# P = np.array([[1, 0], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [0, 1]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
# PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])
PSY[0, 0] = np.array([1, 0])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_8"
exp_code_chapter=1
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験8-2
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ \frac{1}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 0 \\ 1 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
# P = np.array([[1, 0], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [0, 1]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)

PSY[0, 0] = np.array([0, 1])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_8"
exp_code_chapter=2
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験8-3
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\ 0 & 0 \end{matrix}\right]$,
# $Q=\left[\begin{matrix} 0 & 0 \\ \frac{1}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} \frac{1}{\sqrt{2}}  \\ \frac{i}{\sqrt{2}}  \end{matrix}\right]$
# $\psi_t(x)=\left[\begin{matrix} 0\\ 0 \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
P = np.array([[1 / np.sqrt(2), 1 / np.sqrt(2)], [0, 0]], dtype=np.complex128)
Q = np.array([[0, 0], [1 / np.sqrt(2), -1 / np.sqrt(2)]], dtype=np.complex128)
# P = np.array([[1, 0], [0, 0]], dtype=np.complex128)
# Q = np.array([[0, 0], [0, 1]], dtype=np.complex128)
# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY[0, 0] = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])
# PSY[0, 0] = np.array([1, 0])

"""プロット設定"""
# plotしたい時間t。リストで指定。複数指定の場合の例：plots_t = [0, 1, 2, 3]
plots_t = [0, 1, 2, 3, 4, 5, 10, 20, 50, 100, 200, 500]
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの横軸をそれぞれのグラフで最後のx軸の幅に固定するか？
is_solid_axis_x = False
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_8"
exp_code_chapter=3
exp_func.quantum_walk_1d(exp_code,exp_code_chapter, T, P, Q, PSY, plots_t, plot_graph_num_by_axis_row, plot_graph_num_by_axis_col,
                         is_solid_axis_x, graph_type)

# %% [markdown]
# ### 実験名：実験9-1
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} \cos\theta & \sin\theta \\ 0 & 0 \end{matrix}\right]$
# $Q=\left[\begin{matrix} 0 & 0 \\ \sin\theta & -\cos\theta \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 1 \\ 0 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
theta_list = [i * np.pi / 12 for i in range(0,12)]
P_list=[]
Q_list=[]
for theta in theta_list:
    P = np.array([[np.cos(theta), np.sin(theta)], [0, 0]], dtype=np.complex128)
    Q = np.array([[0, 0], [np.sin(theta), -np.cos(theta)]], dtype=np.complex128)
    P_list.append(P)
    Q_list.append(Q)

# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY_init = np.array([1, 0])
PSY[0, 0] = PSY_init

"""プロット設定"""
# plotしたい時間t。
plot_t = 500
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_9"
exp_code_chapter=1
exp_func.quantum_walk_1d_theta_change(exp_code, exp_code_chapter, T, P_list, Q_list, PSY,PSY_init,theta_list, plot_t,
                                 plot_graph_num_by_axis_row,
                                 plot_graph_num_by_axis_col, graph_type)

# %% [markdown]
# ### 実験名：実験9-2
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} \cos\theta & \sin\theta \\ 0 & 0 \end{matrix}\right]$
# $Q=\left[\begin{matrix} 0 & 0 \\ \sin\theta & -\cos\theta \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} 0 \\ 1 \end{matrix}\right]$,
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
theta_list = [i * np.pi / 12 for i in range(0,12)]
P_list=[]
Q_list=[]
for theta in theta_list:
    P = np.array([[np.cos(theta), np.sin(theta)], [0, 0]], dtype=np.complex128)
    Q = np.array([[0, 0], [np.sin(theta), -np.cos(theta)]], dtype=np.complex128)
    P_list.append(P)
    Q_list.append(Q)

# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY_init = np.array([0, 1])
PSY[0, 0] = PSY_init

"""プロット設定"""
# plotしたい時間t。
plot_t = 500
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_9"
exp_code_chapter=2
exp_func.quantum_walk_1d_theta_change(exp_code, exp_code_chapter, T, P_list, Q_list, PSY,PSY_init,theta_list, plot_t,
                                 plot_graph_num_by_axis_row,
                                 plot_graph_num_by_axis_col, graph_type)

# %% [markdown]
# ### 実験名：実験9-3
#
# ### 実験内容（できるだけ分かりやすく文章で説明）：
#
# $P=\left[\begin{matrix} \cos\theta & \sin\theta \\ 0 & 0 \end{matrix}\right]$
# $Q=\left[\begin{matrix} 0 & 0 \\ \sin\theta & -\cos\theta \end{matrix}\right]$
#
# $\psi_0(0)=\left[\begin{matrix} \frac{1}{\sqrt{2}}  \\ \frac{i}{\sqrt{2}}  \end{matrix}\right]$
# $\psi_t(x)=\left[\begin{matrix} 0  \\ 0  \end{matrix}\right]$ $(x\neq0)$
#
#
# ### 実験結果

# %%
"""実験パラメータ"""
# 最大時間発展T(t=0〜t=T-1まで時間発展させる)
# 最大時間発展T(t=0〜t=Tまで時間発展させる。t=Tを求めるにはT+1まで計算する必要があるため内部ではT+1まで計算している)
T = 500
# P,Q
theta_list = [i * np.pi / 12 for i in range(0,12)]
P_list=[]
Q_list=[]
for theta in theta_list:
    P = np.array([[np.cos(theta), np.sin(theta)], [0, 0]], dtype=np.complex128)
    Q = np.array([[0, 0], [np.sin(theta), -np.cos(theta)]], dtype=np.complex128)
    P_list.append(P)
    Q_list.append(Q)

# 初期確率振幅ベクトル[時間×距離(-T〜T)×2次元ベクトル] x+1やx-1があるので、一つ余分に領域をとっておく
PSY = np.zeros([T+1, 2 * (T + 1) + 1, 2], dtype=np.complex128)
PSY_init = np.array([1/np.sqrt(2), 1j/np.sqrt(2)])
PSY[0, 0] = PSY_init

"""プロット設定"""
# plotしたい時間t。
plot_t = 500
# 1つのグラフ内に複数のグラフを表示させる場合、一列（行）に何個グラフを表示させるようにするか？
plot_graph_num_by_axis_row = 3
plot_graph_num_by_axis_col = 4
# グラフの種類
graph_type = "棒グラフ"

"""実験"""
exp_code = "exp_9"
exp_code_chapter=3
exp_func.quantum_walk_1d_theta_change(exp_code, exp_code_chapter, T, P_list, Q_list, PSY,PSY_init,theta_list, plot_t,
                                 plot_graph_num_by_axis_row,
                                 plot_graph_num_by_axis_col, graph_type)
